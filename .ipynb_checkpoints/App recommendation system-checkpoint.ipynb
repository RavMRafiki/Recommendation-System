# %% [markdown]
# <h1>Reccomendation System</h1>

# %% [markdown]
# <h2>Importing Libraries</h2>

# %%
import numpy as np
import random as rn
import pandas as pd
import seaborn as sns
import re
import math

# %% [markdown]
# <h2>Importing Database</h2>

# %%
apps = pd.read_csv(r"googleplaystore.csv")

# %% [markdown]
# <h1>Data Cleanup</h1>

# %%
apps = apps.drop(columns=['Type', 'Price', 'Genres', 'Last Updated', 'Current Ver'])

# %%
apps['Android Ver'] = apps['Android Ver'].str.replace('[^\d.]', '')
avgVer = pd.to_numeric(apps['Android Ver'], errors='coerce').mean()
apps['Android Ver'] = apps['Android Ver'].replace('', avgVer)
apps['Android Ver'] = apps['Android Ver'].str.replace('.','', regex=True).str.replace(',', '.', regex=True).astype(float)
apps['Size'] = apps['Size'].str.replace('[^\d.]', '')
apps['Installs'] = apps['Installs'].str.replace('[^\d.]', '')

avgSize = pd.to_numeric(apps['Size'], errors='coerce').mean()
apps['Size'] = apps['Size'].replace('', avgSize)
apps = apps.dropna()
apps = apps.astype({'Reviews':'float', 'Size':'float', 'Installs':'float', 'Android Ver':'float'})
apps
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7088\1442659501.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   apps['Android Ver'] = apps['Android Ver'].str.replace('[^\d.]', '')
# C:\Users\user\AppData\Local\Temp\ipykernel_7088\1442659501.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   apps['Size'] = apps['Size'].str.replace('[^\d.]', '')
# C:\Users\user\AppData\Local\Temp\ipykernel_7088\1442659501.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   apps['Installs'] = apps['Installs'].str.replace('[^\d.]', '')
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
#        Rating   Reviews   Size    Installs Content Rating  Android Ver
# 0         4.1     159.0   19.0     10000.0       Everyone        403.0
# 1         3.9     967.0   14.0    500000.0       Everyone        403.0
# 2         4.7   87510.0    8.7   5000000.0       Everyone        403.0
# 3         4.5  215644.0   25.0  50000000.0           Teen         42.0
# 4         4.3     967.0    2.8    100000.0       Everyone         44.0
# ...       ...       ...    ...         ...            ...          ...
# 10832     3.8    1195.0  582.0    100000.0       Everyone         21.0
# 10833     4.8      44.0  619.0      1000.0       Everyone         22.0
# 10834     4.0       7.0    2.6       500.0       Everyone         41.0
# 10836     4.5      38.0   53.0      5000.0       Everyone         41.0
# 10837     5.0       4.0    3.6       100.0       Everyone         41.0
#
# [8045 rows x 8 columns]

# %%
class DataProcessing:
    @staticmethod
    def shuffle(x):
        for i in range(len(x)-1,0,-1):
            j=rn.randint(0,i-1)
            x.iloc[j], x.iloc[i] = x.iloc[i], x.iloc[j]
            
    @staticmethod
    def normalization(x):
        values=x.select_dtypes(exclude="object")
        columnNames=values.columns.tolist()
        for column in columnNames[:-1]:
            data = x.loc[:,column]
            max1=max(data)
            min1=min(data)
            for row in range(0,len(x),1):
                xprim=(x.at[row, column]-min1)/(max1-min1)
                x.at[row, column]=xprim
                
    @staticmethod
    def split(x,k):
        return x[:int(len(x)*k//1)], x[int(len(x)*k//1 +1):]

# %%
DataProcessing.shuffle(apps)

# %%
trainingSet, validatingSet = DataProcessing.split(apps, 0.95)
validatingSet = validatingSet.reset_index(drop=True)
DataProcessing.normalization(validatingSet)
validatingSet
# Out:
#                                             App            Category  Rating  \
# 0                 Camping RV Caravan Parking 3D                GAME   0.575
# 1                            FreshBooks Classic            BUSINESS   0.775
# 2                                Black Survival              FAMILY   0.850
# 3                                      Culver's           LIFESTYLE   0.725
# 4                  Dz Dinars Numbers to letters        PRODUCTIVITY   0.925
# ..                                          ...                 ...     ...
# 397                            Cochrane Library             MEDICAL   0.675
# 398                                 CL Strength  HEALTH_AND_FITNESS   1.000
# 399                          FarmersOnly Dating              DATING   0.500
# 400                   Discord - Chat for Gamers       COMMUNICATION   0.875
# 401  Toilet Ek Prem Katha Songs Lyrics in Hindi              FAMILY   0.925
#
#           Reviews      Size      Installs Content Rating  Android Ver
# 0    5.045244e-04  0.054431  4.999950e-04       Everyone         23.0
# 1    1.717997e-04  0.028844  9.999500e-05       Everyone         42.0
# 2    4.621707e-03  0.059084  9.999950e-04           Teen        403.0
# 3    1.561555e-04  0.004303  9.999500e-05       Everyone         43.0
# 4    2.676679e-04  0.010002  9.999500e-05       Everyone        403.0
# ..            ...       ...           ...            ...          ...
# 397  1.907825e-07  0.010235  9.500000e-08       Everyone         41.0
# 398  1.907825e-07  0.045127  4.500000e-08       Everyone         41.0
# 399  1.092230e-04  0.000233  9.999500e-05     Mature 17+         40.0
# 400  2.912734e-02  0.043964  9.999995e-03           Teen         41.0
# 401  1.907825e-07  0.000930  9.950000e-07       Everyone         41.0
#
# [402 rows x 8 columns]

# %% [markdown]
# <h2>k-nearest neighbors algorithm</h2>

# %%
class KNN:
    @staticmethod
    def distance(v1, v2):
        return math.sqrt(math.pow(v1[2] - v2[2], 2) + math.pow(v1[3] - v2[3], 2) + math.pow(v1[4] - v2[4], 2) + math.pow(v1[5] - v2[5], 2))
    def clustering(dataset, sample):
        distances = []
        for i in range(len(dataset)):
            distances.append(KNN.distance(sample, dataset.iloc[i]))
        dataset["distance"] = distances
        dataset = dataset.sort_values("distance")
        
            
        return dataset.head(10)

# %% [markdown]
# <h2>Apps Recommendation</h2>

# %%
avgRating = pd.to_numeric(validatingSet['Rating'], errors='coerce').mean()
avgReviews = pd.to_numeric(validatingSet['Reviews'], errors='coerce').mean()
avgSize = pd.to_numeric(validatingSet['Size'], errors='coerce').mean()
avgInstalls = pd.to_numeric(validatingSet['Installs'], errors='coerce').mean()
avgApp = pd.DataFrame(columns=['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Content Rating', 'Android Ver'])
avgApp.loc[0] = ['a', 'b', avgRating, avgReviews, avgSize, avgInstalls, 'c', 'd']
recommendedApps = KNN.clustering(trainingSet, avgApp.loc[0])
recommendedApps
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7088\783397460.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["distance"] = distances
#                                                    App       Category  Rating  \
# 4038                                           CQ ESPM       BUSINESS     5.0
# 10088                              EB Cash Collections       BUSINESS     5.0
# 2903   Anatomy & Physiology Vocabulary Exam Review App        MEDICAL     5.0
# 4344                                   Tablet Reminder        MEDICAL     5.0
# 6193                                         CB Heroes         SOCIAL     5.0
# 1954                                 Clinic Doctor EHr        MEDICAL     5.0
# 5042                                             LC-DB    PHOTOGRAPHY     3.0
# 8444                                        DK Browser  COMMUNICATION     4.0
# 9676                        PhotoFrame for Synology DS    PHOTOGRAPHY     4.0
# 3794                DG OFF - 100% Free Coupons & Deals       SHOPPING     5.0
#
#        Reviews  Size  Installs Content Rating  Android Ver   distance
# 4038       2.0   3.4       5.0       Everyone         41.0   7.603506
# 10088      1.0   4.3       5.0       Everyone         44.0   7.857137
# 2903       1.0   4.6       5.0       Everyone         40.0   8.023856
# 4344       4.0   2.5       5.0       Everyone         41.0   8.028306
# 6193       5.0   1.8       5.0       Everyone         50.0   8.392706
# 1954       2.0   7.1       5.0       Everyone         80.0   9.817727
# 5042       1.0   2.5      10.0       Everyone         42.0  10.568048
# 8444       1.0   2.4      10.0       Everyone         42.0  10.799137
# 9676       1.0   2.6      10.0       Everyone         40.0  10.844651
# 3794       1.0   1.1      10.0       Everyone         40.0  10.935650
