# %% [markdown]
# <h1>Recommendation System</h1>

# %% [markdown]
# <h2>Importing Libraries</h2>

# %%
import numpy as np
import random as rn
import pandas as pd
import seaborn as sns
import math

# %% [markdown]
# <h2>Importing Database</h2>

# %%
apps = pd.read_csv(r"googleplaystore.csv")
apps.drop([10472], inplace=True)

# %%
apps.sort_values(by=['Reviews'], ascending=False)
# Out:
#                                                     App           Category  \
# 2544                                           Facebook             SOCIAL
# 3943                                           Facebook             SOCIAL
# 381                                  WhatsApp Messenger      COMMUNICATION
# 336                                  WhatsApp Messenger      COMMUNICATION
# 3904                                 WhatsApp Messenger      COMMUNICATION
# ...                                                 ...                ...
# 9713                                          eP Finder  AUTO_AND_VEHICLES
# 8495                                     HDWallpaper DK    PERSONALIZATION
# 6277                                   Bi-Tank Ads Free               GAME
# 8489                               DK Primrose for KLWP    PERSONALIZATION
# 5086  Apps for SportsBєtting.ag - Bitcoin Welcome here!             SPORTS
#
#       Rating   Reviews        Size        Installs  Type  Price  \
# ...

# %%
type(apps['Rating'][8489])
# Out:
# numpy.float64

# %% [markdown]
# <h1>Data Cleanup</h1>

# %%
class DataCleanup:
    @staticmethod
    def mean(column):
        return np.nanmean(column)
    @staticmethod
    def stv(column, mean1):
        tmp=0
        for i in column:
            tmp+=(i-mean1)**2
        print(tmp)
        return np.sqrt(tmp/len(column))
    @staticmethod
    def size_to_int(x):
        if x == 'Varies with device':
            return x
        if 'k' in x:
            if len(x) > 1:
                return int(float(x.replace('k', '')) * 1000)
            return 1000
        if 'M' in x:
            if len(x) > 1:
                return int(float(x.replace('M', '')) * 1000000)
            return 1000000
        if 'B' in x:
            return int(float(x.replace('B', '')) * 1000000000)
        return int(float(x))
    @staticmethod
    def reviews_to_int(x):
        return int(float(x))
    @staticmethod
    def installs_to_int(x):
        if '+' in x:
            return int(x.replace('+', '').replace(',', ''))
        return int(x)
    @staticmethod
    def delete_nan_ratings(x):
        if math.isnan(x):
            return 0
        return x
    @staticmethod
    def genres_split(x):
        return x.split(';')

# %%
apps['Reviews'] = apps['Reviews'].apply(DataCleanup.reviews_to_int)

# %%
apps['Size'] = apps['Size'].apply(DataCleanup.size_to_int)

# %%
apps = apps.dropna(subset=['Rating'])

# %%
apps['Installs'] = apps['Installs'].apply(DataCleanup.installs_to_int)

# %%
apps['Genres'] = apps['Genres'].apply(DataCleanup.genres_split)

# %%
apps.sort_values(by=['Installs'], ascending=False)
# Out:
#                                 App            Category  Rating  Reviews  \
# 3816                    Google News  NEWS_AND_MAGAZINES     3.9   877643
# 3996   Google Chrome: Fast & Secure       COMMUNICATION     4.3  9642112
# 451                           Gmail       COMMUNICATION     4.3  4604483
# 3117      Maps - Navigate & Explore    TRAVEL_AND_LOCAL     4.3  9235155
# 9844                    Google News  NEWS_AND_MAGAZINES     3.9   878065
# ...                             ...                 ...     ...      ...
# 2484              Clinic Doctor EHr             MEDICAL     5.0        2
# 2450                Tablet Reminder             MEDICAL     5.0        4
# 2454            KBA-EZ Health Guide             MEDICAL     5.0        4
# 10697                       Mu.F.O.                GAME     5.0        2
# 5917                       Ra Ga Ba                GAME     5.0        2
#
#                      Size    Installs  Type  Price Content Rating  \
# ...

# %%
type(apps['Last Updated'][3816])
# Out:
# str
