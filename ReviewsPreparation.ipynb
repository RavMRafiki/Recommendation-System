# %% [markdown]
# <h1>Reviews Preparation</h1>

# %%
import numpy as np
import random as rn
import pandas as pd
import seaborn as sns

# %% [markdown]
# <h2>Database Import</h2>

# %%
reviews = pd.read_csv(r"googleplaystore_user_reviews.csv")

# %%
display(reviews)
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %%
reviews = reviews.drop(columns=['Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity'])

# %%
reviews = reviews.dropna()

# %%
display(reviews)
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review
# 0      I like eat delicious food. That's I'm cooking ...
# 1        This help eating healthy exercise regular basis
# 3             Works great especially going grocery store
# 4                                           Best idea us
# 5                                               Best way
# ...                                                  ...
# 64222  Most ads older many agents ..not much owner po...
# 64223  If photos posted portal load, fit purpose. I'm...
# 64226  Dumb app, I wanted post property rent give opt...
# 64227  I property business got link SMS happy perform...
# 64230  Useless app, I searched flats kondapur, Hydera...
#
# [37427 rows x 2 columns]

# %%
apps = reviews["App"].unique().tolist()
appsReviews = []

# %%
appsReviews = []
for app in apps:
    revs = []
    for index in reviews.index:
        if app == reviews.loc[index,'App']:
            revs.append(reviews.loc[index,'Translated_Review'])
    revs = " ".join(revs).lower()
    revs = revs.split(" ")
    words = {}
    for word in revs:
            words[word] = 0
    for word in revs:
            words[word] +=1
    revs = []
    for i in ["i","like","it","its","it's","very","so","the","a","i've","but","do","does","to","dont","is","this"]:
        try:
            del words[i]
        except:
            pass
    for i in range(5):
        try:
            revs.append(max(words, key=words.get))
            del words[max(words, key=words.get)]
        except:
            print(revs)
    appsReviews.append(";".join(revs))
# Out:
# ['really', 'great']
# ['really', 'great']
# ['really', 'great']
# ["don't", 'time', 'spent']
# ["don't", 'time', 'spent']
# ['just', 'good']
# ['just', 'good']
# ['just', 'good']
# ['great', 'good']
# ['great', 'good']
# ['great', 'good']
# ['useful']
# ['useful']
# ['useful']
# ['useful']
# ['front', 'camera', 'error']
# ['front', 'camera', 'error']
# ['best', 'homework', 'world']
# ['best', 'homework', 'world']

# %%
print(appsReviews)
# Out:
# ['good;best;great;food;healthy', 'easy;good;job;nice;mobile', 'and;not;you;for;there', 'easy;order;super;love;contacts', 'game;love;nice;many;ads', "good;keyboard;emoji;can't;really", 'meditation;love;day;full;review', 'users;dating;good;send;many', 'in;not;application;you;of', 'good;nice;find;really;great', 'error;calls;make;create;really', 'great;workout;love;easy;really', '.;highlights;amazing;,;may', 'best;working;used;live;colorado', 'game;great;could;excellent;better', "wallpapers;they're;4k;look;nice", 'not;for;of;and;be', 'of;english;filtering;criteria;lot', 'people;listeners;get;help;connect', 'free;open;it.;every;7', 'exercise;great;music;workout.;need', 'habit;time;think;really;great', 'game;get;play;coins;game.', 'sports;great;love;app.;good', "love;workouts;workout;i'm;meal", 'english;chinese;nice;what;bad', 'santa;call;good;real;said', 'words;awordaday;only;problem;keep', 'watch;great;love;commercials;many', 'good;delete;album;gallery;app.', 'love;easy;check;pay;deposit', 'my;loves;game;good;kids', 'news;abc;news.;notifications;want', 'love;letters;brother;old;good', "my;can't;son;it.;know", "ads;news;good;android;can't", 'love;&;money;card;ace', 'not;and;of;news;on', 'good;amc;annoying;getting;another', 'not;check;flight;english;mobile', 'aol;new;email;emails;open', 'news;review;full;article;story', 'good;nice;weather;really;love', 'love;good;best;ads;much', 'news;good;working;need;channel', 'good;live;not;ads;think', 'easy;great;love;asos;items', 'call;phone;calls;asus;calling', ',;need;asus;improve;as', 'personally,;making;sense!;2;strings', 'good;nice;quality;easy;add', 'notes;note;page;save;account.', 'several;easy;phone;app.;years', 'wifi;never;galaxy;home;phone,', 'voicemail;get;app.;new;visual', 'avg;get;good;app.;phone', 'day;good;get;really;first', "sony;phone;can't;update;xperia", 'great;good;accounting;need;business', 'weather;fix;really;crashes;widget', 'full;back;cast;video;review', 'started;using;update;account;would', 'great;you;google;business;time', 'questions;symptoms;ada;good;helpful', 'text;add;get;good;perfect', 'adobe;pdf;open;app.;file', 'really;great;picture;adobe;editing', 'update;used;phone;android;still', 'game;play;get;fix;people', 'age;need;good;u;nice', 'easy;hotel;and;booking;agoda', 'planes;altitude;aircraft;flying;flight', "login;can't;connection;big;password", 'great;good;used;best;easy', 'airbnb;would;even;booking;great', "flight;good;can't;great;airport", "great;game;controls;realistic;can't", 'game;vip;guess;even;says', 'best;text;read;reading;add', "alarm;set;go;can't;always", 'alarm;go;time;used;work', 'great;ads;free;going;upgrade', 'app.;price;buy;really;received', 'ads;great;ok.....!;never;let', 'events;app.;event;organisers;best', 'best;football;love;everything;news', 'good;live;app,;best;sports', 'language;translate;much;good;nice', 'best;math;studying;hard;ads', "mental;disorders;best;i'm;went", 'every;ads;time;good;pop', 'good;videos;best;love;super', 'works;good;app.;love;clear', 'love;let;go;lack;room', 'made;airline;experience;lot;better.', 'recipes;recipe;make;great;love', 'game;game.;great;game,;get', 'amazon;drive;storage;cloud;good', 'content;able;kids;love;access', 'kindle;books;book;read;new', 'great;works;amazingly.;reliable;decides', 'amazon;love;good;app.;always', 'update;australian;still;amazon;store.', 'flight;boarding;gate;check;pass', 'app.;log;credit;great;update', 'amino;friends;get;new;love', 'train;reservation;number;not;even', 'great;would;3d;love;really', 'family;tree;great;easy;update', 'even;app.;file;used;unzip', 'car;music;android;google;app.', 'messages;group;app.;messaging;sent', 'game;good;really;cool;keeps', 'game;birds;get;angry;love', 'game;play;get;ads;love', 'game;add;ads;play;get', 'love;shows;great;animal;watch', 'good;love;nice;bad;awesome', 'make;could;wish;ads;hate', 'love;color;good;anime;thing', "can't;login;log;information.;even", "can't;get;id;even;login", 'tasks;update;love;even;want', 'useful;practical;young;owner;me.', 'g ...

# %%
d = {'App': apps, 'reviews': appsReviews}
dfToWrite = pd.DataFrame(data=d)
dfToWrite.to_csv (r'processedReviews.csv', index = None, header=True)

# %%
display(dfToWrite)
# Out:
#                                                    App  \
# 0                                10 Best Foods for You
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2                                                 11st
# 3                           1800 Contacts - Lens Store
# 4                      1LINE – One Line with One Touch
# ..                                                 ...
# 860  Hotels.com: Book Hotel Rooms & Find Vacation D...
# 861     Hotspot Shield Free VPN Proxy & Wi-Fi Security
# 862                                            Hotstar
# 863                     Hotwire Hotel & Car Rental App
# 864                     Housing-Real Estate & Property
#
#                             reviews
# 0      good;best;great;food;healthy
# 1         easy;good;job;nice;mobile
# 2             and;not;you;for;there
# 3    easy;order;super;love;contacts
# 4           game;love;nice;many;ads
# ..                              ...
# 860        hotel;book;pet;find;good
# 861          good;7;days;free;trial
# 862      shows;answer;u;please;time
# 863    would;hotels;hotel;app.;they
# 864  property;posted;.;agents;price
#
# [865 rows x 2 columns]

# %%
print(apps)
# Out:
# ['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', '11st', '1800 Contacts - Lens Store', '1LINE – One Line with One Touch', '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif', '21-Day Meditation Experience', '2Date Dating App, Love and matching', '2GIS: directory & navigator', '2RedBeans', '2ndLine - Second Phone Number', '30 Day Fitness Challenge - Workout at Home', '365Scores - Live Scores', '3D Live Neon Weed Launcher', '4 in a Row', '4K Wallpapers and Ultra HD Backgrounds', '591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢', '591房屋交易-香港', '7 Cups: Anxiety & Stress Chat', '7 Day Food Journal Challenge', '7 Minute Workout', '7 Weeks - Habit & Goal Tracker', '8 Ball Pool', '850 Sports News Digest', '8fit Workouts & Meal Planner', '95Live -SG#1 Live Streaming App', 'A Call From Santa Claus!', 'A Word A Day', 'A&E - Watch Full Episodes of TV Shows', 'A+ Gallery - Photos & Videos', 'A+ Mobile', 'ABC Kids - Tracing & Phonics', 'ABC News - US & World News', 'ABC Preschool Free', 'ABCmouse.com', 'AC - Tips & News for Android™', 'ACE Elite', 'AD - Nieuws, Sport, Regio & Entertainment', 'AMC Theatres', 'ANA', 'AOL - News, Mail & Video', 'AP Mobile - Breaking News', 'APE Weather ( Live Forecast)', 'APUS Launcher - Theme, Wallpaper, Hide Apps', 'ARY NEWS', 'ARY NEWS URDU', 'ASOS', 'ASUS Calling Screen', 'ASUS Cover for ZenFone 2', 'ASUS Quick Memo', 'ASUS Sound Recorder', 'ASUS SuperNote', 'AT&T Navigator: Maps, Traffic', 'AT&T Smart Wi-Fi', 'AT&T Visual Voicemail', 'AVG Cleaner – Speed, Battery & Memory Booster', 'Abs Training-Burn belly fat', 'Account Manager', 'Accounting App - Zoho Books', 'AccuWeather: Daily Forecast & Live Weather Reports', 'Acorn TV: World-class TV from Britain and Beyond', 'Acorns - Invest Spare Change', 'AdWords Express', 'Ada - Your Health Guide', 'Add Text To Photo', 'Adobe Acrobat Reader', 'Adobe Photoshop Express:Photo Editor Collage Maker', 'Advanced Task Killer', 'Agar.io', 'Age Calculator', 'Agoda – Hotel Booking Deals', 'Air Traffic', 'AirAsia', 'AirBrush: Easy Photo Editor', 'Airbnb', 'Airport + Flight Tracker Radar', 'Airway Ex - Intubate. Anesthetize. Train.', 'Akinator', 'AlReader -any text book reader', 'Alarm Clock', 'Alarm Clock Free', 'Alfred Home Security Camera', 'AliExpress - Smarter Shopping, Better Living', 'All Email Providers', 'All Events in City', 'All Football - Latest News & Videos', 'All Football GO- Live Score, Games', 'All Language Translator Free', 'All Maths Formulas', 'All Mental disorders', 'All Social Networks', 'All Video Downloader 2018', 'All-In-One Toolbox: Cleaner, Booster, App Manager', 'All-in-One Mahjong 3 FREE', 'Allegiant', 'Allrecipes Dinner Spinner', "Alto's Adventure", 'Amazon Drive', 'Amazon FreeTime – Kids’ Videos, Books, & TV shows', 'Amazon Kindle', 'Amazon Prime Video', 'Amazon Shopping', 'Amazon for Tablets', 'American Airlines', 'Amex Mobile', 'Amino: Communities and Chats', 'Amtrak', 'Anatomy Learning - 3D Atlas', 'Ancestry', 'AndroZip™ FREE File Manager', 'Android Auto - Maps, Media, Messaging & Voice', 'Android Messages', 'Anger of stick 5 : zombie', 'Angry Birds 2', 'Angry Birds Classic', 'Angry Birds Rio', 'Animal Planet GO', 'Animated Photo Editor', 'Anime Avatar Creator: Make Your Own Avatar', 'Anime Manga Coloring Book', 'Anthem Anywhere', 'Anthem BC Anywhere', 'Any.do: To-do list, Calendar, Reminders & Planner', 'Apartment Decorating Ideas', 'Apartment List: Housing, Apt, and Property Rentals', 'Apartment, Home Rental Search: Realtor.com Rentals', 'Apartments & Rentals - Zillow', 'Apartments.com Rental Search', 'Apex Launcher', 'Apk Installer', 'App vault', 'AppLock', 'AppLock - Fingerprint', 'Apple Daily 蘋果動新聞', 'Aprender inglés con Wlingua', 'Archos File Manager', 'Arrow.io', 'Asana: organize team projects', 'Ascape VR: 360° Virtual Travel', 'Asphalt 8: Airborne', 'Associated Credit Union Mobile', 'Asteroids 3D live wallpaper', 'Atlan3D Navigation: Korea navigator', 'AutoCAD - DWG Viewer & Editor', 'AutoScout24 Switzerland – Find yo ...
